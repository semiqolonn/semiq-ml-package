# %%
from sklearn.datasets import load_iris

df = load_iris(as_frame=True).frame
X = df.drop(columns='target')
y = df['target']

# %% [markdown]
# # BaselineModel test

# %%
from semiq_ml.baseline_model import BaselineModel

baseline = BaselineModel(
    task_type="classification",
    metric="f1_weighted",
    models="gbm",
    random_state=42,
)
baseline.fit(X, y)

baseline.get_results()
# Out:
# 2025-06-12 10:03:44,843 - INFO - Starting BaselineModel training for classification with metric: f1_weighted (Maximize: True)
# 2025-06-12 10:03:44,843 - INFO - Validation set size: 20%
# 2025-06-12 10:03:44,844 - INFO - Preprocessor type: general_ohe
# 2025-06-12 10:03:44,844 - INFO - Numeric columns: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# 2025-06-12 10:03:44,844 - INFO - Categorical columns: []
# 2025-06-12 10:03:44,843 - INFO - Validation set size: 20%
# 2025-06-12 10:03:44,844 - INFO - Preprocessor type: general_ohe
# 2025-06-12 10:03:44,844 - INFO - Numeric columns: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# 2025-06-12 10:03:44,844 - INFO - Categorical columns: []
# /home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# 2025-06-12 10:03:44,923 - INFO -   LGBM f1_weighted: train=1.0000, val=0.8997 (Time: 0.08s)
# 2025-06-12 10:03:44,924 - INFO -   --> NEW BEST model: LGBM with f1_weighted: 0.8997
# /home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# 2025-06-12 10:03:44,923 - INFO -   LGBM f1_weighted: train=1.0000, val=0.8997 (Time: 0.08s)
# 2025-06-12 10:03:44,924 - INFO -   --> NEW BEST model: LGBM with f1_weighted: 0.8997
# 2025-06-12 10:03:45,131 - INFO -   XGBoost f1_weighted: train=1.0000, val=0.9333 (Time: 0.21s)
# 2025-06-12 10:03:45,131 - INFO -   --> NEW BEST model: XGBoost with f1_weighted: 0.9333
# 2025-06-12 10:03:45,131 - INFO -   XGBoost f1_weighted: train=1.0000, val=0.9333 (Time: 0.21s)
# 2025-06-12 10:03:45,131 - INFO -   --> NEW BEST model: XGBoost with f1_weighted: 0.9333
# 2025-06-12 10:03:45,365 - INFO -   CatBoost f1_weighted: train=1.0000, val=0.9666 (Time: 0.23s)
# 2025-06-12 10:03:45,366 - INFO -   --> NEW BEST model: CatBoost with f1_weighted: 0.9666
# 2025-06-12 10:03:45,366 - INFO - BaselineModel run complete. Best model: CatBoostClassifier with f1_weighted: 0.9666
# 2025-06-12 10:03:45,365 - INFO -   CatBoost f1_weighted: train=1.0000, val=0.9666 (Time: 0.23s)
# 2025-06-12 10:03:45,366 - INFO -   --> NEW BEST model: CatBoost with f1_weighted: 0.9666
# 2025-06-12 10:03:45,366 - INFO - BaselineModel run complete. Best model: CatBoostClassifier with f1_weighted: 0.9666
#       model  train_score  val_score  fit_time  preprocessor_used   status  \
# 0      LGBM          1.0   0.899749  0.079636        general_ohe  Success
# 1   XGBoost          1.0   0.933333  0.206494        general_ohe  Success
# 2  CatBoost          1.0   0.966583  0.233932  catboost_internal  Success
#
#   error_message
# 0
# 1
# 2

# %% [markdown]
# # OptunaOptimizer

# %%
from semiq_ml.tuning import OptunaOptimizer
tuner = OptunaOptimizer(
    task_type="classification",
    metric="f1_weighted",
    n_trials=5,
    gpu=True,
)

# Check n_trials before running tuning
print(f"n_trials configured for XGBoost: {tuner.n_trials['XGBoost']}")

# Set a very small number of trials and short timeout for quick testing
tuned_xgb = tuner.tune_model("LGBM", X, y, n_jobs=1)
tuner.get_tuning_results()
# Out:
# 2025-06-12 10:07:06,450 - INFO - Starting hyperparameter optimization for LGBM
# 2025-06-12 10:07:06,450 - INFO - Number of trials: 5, timeout: None
# [I 2025-06-12 10:07:06,451] A new study created in memory with name: no-name-9cff0cb8-12b8-46a3-b066-462bfc95f79c
# 2025-06-12 10:07:06,450 - INFO - Number of trials: 5, timeout: None
# [I 2025-06-12 10:07:06,451] A new study created in memory with name: no-name-9cff0cb8-12b8-46a3-b066-462bfc95f79c
# n_trials configured for XGBoost: 5
#   0%|          | 0/5 [00:00<?, ?it/s]2025-06-12 10:07:06,455 - INFO - Preprocessor type: general_ohe
# 2025-06-12 10:07:06,455 - INFO - Numeric columns: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# 2025-06-12 10:07:06,455 - INFO - Categorical columns: []
# 2025-06-12 10:07:06,455 - INFO - Preprocessor type: general_ohe
# 2025-06-12 10:07:06,455 - INFO - Numeric columns: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# 2025-06-12 10:07:06,455 - INFO - Categorical columns: []
# [LightGBM] [Fatal] Number of classes must be 1 for non-multiclass training
# 2025-06-12 10:07:06,464 - ERROR - Error in trial for LGBM: Number of classes must be 1 for non-multiclass training
# Traceback (most recent call last):
#   File "/mnt/data/Projects/semiq-ml/semiq_ml/tuning.py", line 285, in _objective
#     model_instance.fit(X_train_proc, y_train)
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1560, in fit
#     super().fit(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1049, in fit
#     self._Booster = train(
#                     ^^^^^^
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/engine.py", line 297, in train
#     booster = Booster(params=params, train_set=train_set)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 3656, in __init__
#     train_set.construct()
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2590, in construct
#     self._lazy_init(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2187, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2318, in __init_from_np2d
#     _safe_call(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 313, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
# lightgbm.basic.LightGBMError: Number of classes must be 1 for non-multiclass training
#   0%|          | 0/5 [00:00<?, ?it/s][LightGBM] [Fatal] Number of classes must be 1 for non-multiclass training
# 2025-06-12 10:07:06,472 - ERROR - Error in trial for LGBM: Number of classes must be 1 for non-multiclass training
# Traceback (most recent call last):
#   File "/mnt/data/Projects/semiq-ml/semiq_ml/tuning.py", line 285, in _objective
#     model_instance.fit(X_train_proc, y_train)
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1560, in fit
#     super().fit(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1049, in fit
#     self._Booster = train(
#                     ^^^^^^
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/engine.py", line 297, in train
#     booster = Booster(params=params, train_set=train_set)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 3656, in __init__
#     train_set.construct()
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2590, in construct
#     self._lazy_init(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2187, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2318, in __init_from_np2d
#     _safe_call(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 313, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
# lightgbm.basic.LightGBMError: Number of classes must be 1 for non-multiclass training
#  20%|██        | 1/5 [00:00<00:00, 46.15it/s][LightGBM] [Fatal] Number of classes must be 1 for non-multiclass training
# 2025-06-12 10:07:06,464 - ERROR - Error in trial for LGBM: Number of classes must be 1 for non-multiclass training
# Traceback (most recent call last):
#   File "/mnt/data/Projects/semiq-ml/semiq_ml/tuning.py", line 285, in _objective
#     model_instance.fit(X_train_proc, y_train)
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1560, in fit
#     super().fit(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1049, in fit
#     self._Booster = train(
#                     ^^^^^^
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/engine.py", line 297, in train
#     booster = Booster(params=params, train_set=train_set)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 3656, in __init__
#     train_set.construct()
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2590, in construct
#     self._lazy_init(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2187, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2318, in __init_from_np2d
#     _safe_call(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 313, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
# lightgbm.basic.LightGBMError: Number of classes must be 1 for non-multiclass training
#   0%|          | 0/5 [00:00<?, ?it/s][LightGBM] [Fatal] Number of classes must be 1 for non-multiclass training
# 2025-06-12 10:07:06,472 - ERROR - Error in trial for LGBM: Number of classes must be 1 for non-multiclass training
# Traceback (most recent call last):
#   File "/mnt/data/Projects/semiq-ml/semiq_ml/tuning.py", line 285, in _objective
#     model_instance.fit(X_train_proc, y_train)
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1560, in fit
#     super().fit(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1049, in fit
#     self._Booster = train(
#                     ^^^^^^
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/engine.py", line 297, in train
#     booster = Booster(params=params, train_set=train_set)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 3656, in __init__
#     train_set.construct()
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2590, in construct
#     self._lazy_init(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2187, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2318, in __init_from_np2d
#     _safe_call(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 313, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
# lightgbm.basic.LightGBMError: Number of classes must be 1 for non-multiclass training
#  20%|██        | 1/5 [00:00<00:00, 46.15it/s][LightGBM] [Fatal] Number of classes must be 1 for non-multiclass training
# 2025-06-12 10:07:06,480 - ERROR - Error in trial for LGBM: Number of classes must be 1 for non-multiclass training
# Traceback (most recent call last):
#   File "/mnt/data/Projects/semiq-ml/semiq_ml/tuning.py", line 285, in _objective
#     model_instance.fit(X_train_proc, y_train)
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1560, in fit
#     super().fit(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1049, in fit
#     self._Booster = train(
#                     ^^^^^^
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/engine.py", line 297, in train
#     booster = Booster(params=params, train_set=train_set)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 3656, in __init__
#     train_set.construct()
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2590, in construct
#     self._lazy_init(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2187, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2318, in __init_from_np2d
#     _safe_call(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 313, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
# lightgbm.basic.LightGBMError: Number of classes must be 1 for non-multiclass training
#  40%|████      | 2/5 [00:00<00:00, 67.30it/s][LightGBM] [Fatal] Number of classes must be 1 for non-multiclass training
# 2025-06-12 10:07:06,487 - ERROR - Error in trial for LGBM: Number of classes must be 1 for non-multiclass training
# Traceback (most recent call last):
#   File "/mnt/data/Projects/semiq-ml/semiq_ml/tuning.py", line 285, in _objective
#     model_instance.fit(X_train_proc, y_train)
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1560, in fit
#     super().fit(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1049, in fit
#     self._Booster = train(
#                     ^^^^^^
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/engine.py", line 297, in train
#     booster = Booster(params=params, train_set=train_set)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 3656, in __init__
#     train_set.construct()
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2590, in construct
#     self._lazy_init(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2187, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2318, in __init_from_np2d
#     _safe_call(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 313, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
# lightgbm.basic.LightGBMError: Number of classes must be 1 for non-multiclass training
#  60%|██████    | 3/5 [00:00<00:00, 81.25it/s][LightGBM] [Fatal] Number of classes must be 1 for non-multiclass training
# 2025-06-12 10:07:06,480 - ERROR - Error in trial for LGBM: Number of classes must be 1 for non-multiclass training
# Traceback (most recent call last):
#   File "/mnt/data/Projects/semiq-ml/semiq_ml/tuning.py", line 285, in _objective
#     model_instance.fit(X_train_proc, y_train)
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1560, in fit
#     super().fit(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1049, in fit
#     self._Booster = train(
#                     ^^^^^^
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/engine.py", line 297, in train
#     booster = Booster(params=params, train_set=train_set)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 3656, in __init__
#     train_set.construct()
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2590, in construct
#     self._lazy_init(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2187, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2318, in __init_from_np2d
#     _safe_call(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 313, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
# lightgbm.basic.LightGBMError: Number of classes must be 1 for non-multiclass training
#  40%|████      | 2/5 [00:00<00:00, 67.30it/s][LightGBM] [Fatal] Number of classes must be 1 for non-multiclass training
# 2025-06-12 10:07:06,487 - ERROR - Error in trial for LGBM: Number of classes must be 1 for non-multiclass training
# Traceback (most recent call last):
#   File "/mnt/data/Projects/semiq-ml/semiq_ml/tuning.py", line 285, in _objective
#     model_instance.fit(X_train_proc, y_train)
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1560, in fit
#     super().fit(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1049, in fit
#     self._Booster = train(
#                     ^^^^^^
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/engine.py", line 297, in train
#     booster = Booster(params=params, train_set=train_set)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 3656, in __init__
#     train_set.construct()
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2590, in construct
#     self._lazy_init(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2187, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2318, in __init_from_np2d
#     _safe_call(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 313, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
# lightgbm.basic.LightGBMError: Number of classes must be 1 for non-multiclass training
#  60%|██████    | 3/5 [00:00<00:00, 81.25it/s][LightGBM] [Fatal] Number of classes must be 1 for non-multiclass training
# 2025-06-12 10:07:06,571 - ERROR - Error in trial for LGBM: Number of classes must be 1 for non-multiclass training
# Traceback (most recent call last):
#   File "/mnt/data/Projects/semiq-ml/semiq_ml/tuning.py", line 285, in _objective
#     model_instance.fit(X_train_proc, y_train)
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1560, in fit
#     super().fit(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1049, in fit
#     self._Booster = train(
#                     ^^^^^^
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/engine.py", line 297, in train
#     booster = Booster(params=params, train_set=train_set)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 3656, in __init__
#     train_set.construct()
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2590, in construct
#     self._lazy_init(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2187, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2318, in __init_from_np2d
#     _safe_call(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 313, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
# lightgbm.basic.LightGBMError: Number of classes must be 1 for non-multiclass training
# 100%|██████████| 5/5 [00:00<00:00, 40.64it/s][LightGBM] [Fatal] Number of classes must be 1 for non-multiclass training
# 2025-06-12 10:07:06,571 - ERROR - Error in trial for LGBM: Number of classes must be 1 for non-multiclass training
# Traceback (most recent call last):
#   File "/mnt/data/Projects/semiq-ml/semiq_ml/tuning.py", line 285, in _objective
#     model_instance.fit(X_train_proc, y_train)
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1560, in fit
#     super().fit(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/sklearn.py", line 1049, in fit
#     self._Booster = train(
#                     ^^^^^^
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/engine.py", line 297, in train
#     booster = Booster(params=params, train_set=train_set)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 3656, in __init__
#     train_set.construct()
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2590, in construct
#     self._lazy_init(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2187, in _lazy_init
#     self.__init_from_np2d(data, params_str, ref_dataset)
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 2318, in __init_from_np2d
#     _safe_call(
#   File "/home/semiqolonn/miniforge3/envs/ml/lib/python3.12/site-packages/lightgbm/basic.py", line 313, in _safe_call
#     raise LightGBMError(_LIB.LGBM_GetLastError().decode("utf-8"))
# lightgbm.basic.LightGBMError: Number of classes must be 1 for non-multiclass training
# 100%|██████████| 5/5 [00:00<00:00, 40.64it/s]
# [I 2025-06-12 10:07:06,466] Trial 0 pruned. Trial for LGBM failed with error: Number of classes must be 1 for non-multiclass training
# [I 2025-06-12 10:07:06,473] Trial 1 pruned. Trial for LGBM failed with error: Number of classes must be 1 for non-multiclass training
# [I 2025-06-12 10:07:06,481] Trial 2 pruned. Trial for LGBM failed with error: Number of classes must be 1 for non-multiclass training
# [I 2025-06-12 10:07:06,488] Trial 3 pruned. Trial for LGBM failed with error: Number of classes must be 1 for non-multiclass training
# [I 2025-06-12 10:07:06,573] Trial 4 pruned. Trial for LGBM failed with error: Number of classes must be 1 for non-multiclass training
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 13
#      10 print(f"n_trials configured for XGBoost: {tuner.n_trials['XGBoost']}")
#      12 # Set a very small number of trials and short timeout for quick testing
# ---> 13 tuned_xgb = tuner.tune_model("LGBM", X, y, n_jobs=1)
#      14 tuner.get_tuning_results()
#
# File /mnt/data/Projects/semiq-ml/semiq_ml/tuning.py:500, in OptunaOptimizer.tune_model(self, model_name, X, y, validation_size, n_jobs)
#     497     logger.info("Optimization interrupted by user.")
#     499 # Get the best parameters and create a model with them
# --> 500 best_params = self.study.best_params
#     501 self.best_params[model_name] = best_params
#     503 # Create a model with the best parameters
#
# File ~/miniforge3/envs/ml/lib/python3.12/site-packages/optuna/study/study.py:119, in Study.best_params(self)
#     107 @property
#     108 def best_params(self) -> dict[str, Any]:
#     109     """Return parameters of the best trial in the study.
#     110
#     111     .. note::
#    (...)    116
#     117     """
# --> 119     return self.best_trial.params
#
# File ~/miniforge3/envs/ml/lib/python3.12/site-packages/optuna/study/study.py:162, in Study.best_trial(self)
#     156 if self._is_multi_objective():
#     157     raise RuntimeError(
#     158         "A single best trial cannot be retrieved from a multi-objective study. Consider "
#     159         "using Study.best_trials to retrieve a list containing the best trials."
#     160     )
# --> 162 best_trial = self._storage.get_best_trial(self._study_id)
#     164 # If the trial with the best value is infeasible, select the best trial from all feasible
#     165 # trials. Note that the behavior is undefined when constrained optimization without the
#     166 # violation value in the best-valued trial.
#     167 constraints = best_trial.system_attrs.get(_CONSTRAINTS_KEY)
#
# File ~/miniforge3/envs/ml/lib/python3.12/site-packages/optuna/storages/_in_memory.py:252, in InMemoryStorage.get_best_trial(self, study_id)
#     249 best_trial_id = self._studies[study_id].best_trial_id
#     251 if best_trial_id is None:
# --> 252     raise ValueError("No trials are completed yet.")
#     253 elif len(self._studies[study_id].directions) > 1:
#     254     raise RuntimeError(
#     255         "Best trial can be obtained only for single-objective optimization."
#     256     )
#
# ValueError: No trials are completed yet.

# %%
# Check the n_trials configuration
print(f"n_trials configured for XGBoost: {tuner.n_trials['XGBoost']}")
# Out:
# n_trials configured for XGBoost: 5
